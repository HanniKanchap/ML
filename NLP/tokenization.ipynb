# %%
import nltk
nltk.download('punkt')
nltk.download('punkt_tab')
# Out:
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\hanni\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package punkt_tab to
# [nltk_data]     C:\Users\hanni\AppData\Roaming\nltk_data...
# [nltk_data]   Unzipping tokenizers\punkt_tab.zip.
# True

# %%
corpus = "Hello world! This is a test corpus for tokenization. I am starting to learn NLP from Krish Naik's NLP tutorial."

# %%
corpus
# Out:
# "Hello world! This is a test corpus for tokenization. I am starting to learn NLP from Krish Naik's NLP tutorial."

# %%
## Tokenization
# Paragraph into Sentences
from nltk.tokenize import sent_tokenize

# %%
sentences = sent_tokenize(text=corpus,language='english')

# %%
from nltk.tokenize import word_tokenize

# %%
sentences
# Out:
# ['Hello world!',
#  'This is a test corpus for tokenization.',
#  "I am starting to learn NLP from Krish Naik's NLP tutorial."]

# %%
word_tokenize(corpus)
# Out:
# ['Hello',
#  'world',
#  '!',
#  'This',
#  'is',
#  'a',
#  'test',
#  'corpus',
#  'for',
#  'tokenization',
#  '.',
#  'I',
#  'am',
#  'starting',
#  'to',
#  'learn',
#  'NLP',
#  'from',
#  'Krish',
#  'Naik',
#  "'s",
#  'NLP',
#  'tutorial',
#  '.']

# %%
from nltk.tokenize import wordpunct_tokenize

# %%
wordpunct_tokenize(corpus)
# Out:
# ['Hello',
#  'world',
#  '!',
#  'This',
#  'is',
#  'a',
#  'test',
#  'corpus',
#  'for',
#  'tokenization',
#  '.',
#  'I',
#  'am',
#  'starting',
#  'to',
#  'learn',
#  'NLP',
#  'from',
#  'Krish',
#  'Naik',
#  "'",
#  's',
#  'NLP',
#  'tutorial',
#  '.']

# %%
from nltk.tokenize import TreebankWordTokenizer

# %%
tokenizer = TreebankWordTokenizer()

# %%
tokenizer.tokenize(corpus)
# Out:
# ['Hello',
#  'world',
#  '!',
#  'This',
#  'is',
#  'a',
#  'test',
#  'corpus',
#  'for',
#  'tokenization.',
#  'I',
#  'am',
#  'starting',
#  'to',
#  'learn',
#  'NLP',
#  'from',
#  'Krish',
#  'Naik',
#  "'s",
#  'NLP',
#  'tutorial',
#  '.']
