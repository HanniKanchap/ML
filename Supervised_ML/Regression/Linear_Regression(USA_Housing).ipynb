# %%
import pandas as pd

# %%
df = pd.read_csv("../../data/USA_Housing.csv")

# %%
df.head()
# Out:
#    Avg. Area Income  Avg. Area House Age  Avg. Area Number of Rooms  \
# 0       79545.45857             5.682861                   7.009188
# 1       79248.64245             6.002900                   6.730821
# 2       61287.06718             5.865890                   8.512727
# 3       63345.24005             7.188236                   5.586729
# 4       59982.19723             5.040555                   7.839388
#
#    Avg. Area Number of Bedrooms  Area Population         Price  \
# 0                          4.09      23086.80050  1.059034e+06
# 1                          3.09      40173.07217  1.505891e+06
# 2                          5.13      36882.15940  1.058988e+06
# 3                          3.26      34310.24283  1.260617e+06
# 4                          4.23      26354.10947  6.309435e+05
#
#                                              Address
# 0  208 Michael Ferry Apt. 674\nLaurabury, NE 3701...
# 1  188 Johnson Views Suite 079\nLake Kathleen, CA...
# 2  9127 Elizabeth Stravenue\nDanieltown, WI 06482...
# 3                          USS Barnett\nFPO AP 44820
# 4                         USNS Raymond\nFPO AE 09386

# %%
df.dtypes
# Out:
# Avg. Area Income                float64
# Avg. Area House Age             float64
# Avg. Area Number of Rooms       float64
# Avg. Area Number of Bedrooms    float64
# Area Population                 float64
# Price                           float64
# Address                          object
# dtype: object

# %%
df.drop('Address',axis =1,inplace =True)

# %%
df.head()
# Out:
#    Avg. Area Income  Avg. Area House Age  Avg. Area Number of Rooms  \
# 0       79545.45857             5.682861                   7.009188
# 1       79248.64245             6.002900                   6.730821
# 2       61287.06718             5.865890                   8.512727
# 3       63345.24005             7.188236                   5.586729
# 4       59982.19723             5.040555                   7.839388
#
#    Avg. Area Number of Bedrooms  Area Population         Price
# 0                          4.09      23086.80050  1.059034e+06
# 1                          3.09      40173.07217  1.505891e+06
# 2                          5.13      36882.15940  1.058988e+06
# 3                          3.26      34310.24283  1.260617e+06
# 4                          4.23      26354.10947  6.309435e+05

# %%
import seaborn as sns
sns.heatmap(df.corr())
# Out:
# <Axes: >

# %%
X = df[['Avg. Area Income']]

# %%
y = df['Price']

# %%
from sklearn.model_selection import train_test_split
X_train , X_test , y_train , y_test = train_test_split(X,y,random_state=42,test_size =0.30)

# %%
from sklearn.linear_model import LinearRegression
reg = LinearRegression()
reg.fit(X_train,y_train)
# Out:
# LinearRegression()

# %%
y_pred = reg.predict(X_test)

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
plt.scatter(X_train,y_train,color ='r')
plt.scatter(X_test,y_test,color = 'y')
plt.plot(X_test,reg.predict(X_test),color ='g')

# %%
from sklearn.metrics import mean_squared_error,r2_score

mean_squared_error(y_test,y_pred)
# Out:
# 71606719100.3831

# %%
r2_score(y_test,y_pred)
# Out:
# 0.39321648660041497

# %%
X = df[['Avg. Area House Age']]
y = df['Price']
X_train , X_test , y_train , y_test = train_test_split(X,y,random_state=42,test_size =0.30)
reg = LinearRegression()
reg.fit(X_train,y_train)
y_pred = reg.predict(X_test)
plt.scatter(X_train,y_train,color ='r')
plt.scatter(X_test,y_test,color = 'y')
plt.plot(X_test,reg.predict(X_test),color ='g')

# %%
print("mse :",mean_squared_error(y_test,y_pred))
print("r2_score: ",r2_score(y_test,y_pred))
# Out:
# mse : 95885507215.85909
# r2_score:  0.18748204521174672

# %%
X = df[['Avg. Area Number of Rooms']]
y = df['Price']
X_train , X_test , y_train , y_test = train_test_split(X,y,random_state=42,test_size =0.30)
reg = LinearRegression()
reg.fit(X_train,y_train)
y_pred = reg.predict(X_test)
plt.scatter(X_train,y_train,color ='r')
plt.scatter(X_test,y_test,color = 'y')
plt.plot(X_test,reg.predict(X_test),color ='g')

# %%
print("mse :",mean_squared_error(y_test,y_pred))
print("r2_score: ",r2_score(y_test,y_pred))
# Out:
# mse : 104809468882.47107
# r2_score:  0.11186186764266903

# %%
X = df[['Avg. Area Number of Bedrooms']]
y = df['Price']
X_train , X_test , y_train , y_test = train_test_split(X,y,random_state=42,test_size =0.30)
reg = LinearRegression()
reg.fit(X_train,y_train)
y_pred = reg.predict(X_test)
plt.scatter(X_train,y_train,color ='r')
plt.scatter(X_test,y_test,color = 'y')
plt.plot(X_test,reg.predict(X_test),color ='g')

# %%
print("mse :",mean_squared_error(y_test,y_pred))
print("r2_score: ",r2_score(y_test,y_pred))
# Out:
# mse : 116135508944.05142
# r2_score:  0.015886874404452023

# %%
X = df[['Area Population']]
y = df['Price']
X_train , X_test , y_train , y_test = train_test_split(X,y,random_state=42,test_size =0.30)
reg = LinearRegression()
reg.fit(X_train,y_train)
y_pred = reg.predict(X_test)
plt.scatter(X_train,y_train,color ='r')
plt.scatter(X_test,y_test,color = 'y')
plt.plot(X_test,reg.predict(X_test),color ='g')

# %%
print("mse :",mean_squared_error(y_test,y_pred))
print("r2_score: ",r2_score(y_test,y_pred))
# Out:
# mse : 98558987371.94144
# r2_score:  0.16482741583489202
